# %%
import pandas

# %%
db = pandas.read_csv('data.csv')

# %%
y = db['marks']

# %%
x = db['hrs']

# %%
x = x.values.reshape(-1,1)

# %%
x
# Out:
# array([[5, 2, 7, 3, 4, 6]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
mind = LinearRegression()

# %%
mind.fit(x, y)
# Out:
# LinearRegression()

# %%
a = mind.predict([[6]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 a = mind.predict([[6]])
# ----> 2 z = a[0][0]
#       3 z
#
# IndexError: invalid index to scalar variable.

# %%
mind.coef_
# Out:
# array([10.])

# %%
import joblib

# %%
joblib.dump(mind,'marks_model')
# Out:
# ['marks_model']

# %%
import joblib

model = joblib.load("marks_model")
hrs = int(input("enter the number of marks you studied"))

p = model.predict([[hrs]])

print(p)
# Out:
# [50.]

# %%
import joblib
from flask import Flask

app  = Flask(__name__)


model = joblib.load("marks_model")
#hrs = int(input("enter the number of marks you studied"))
@app.route("/marks/<hrs>")
def marks(hrs):
    p = model.predict([[hrs]])

    print(p)
    s = p[0][0]
    return str(s)

app.run(port=80, host='0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:80
#  * Running on http://192.168.181.73:80
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Jul/2024 16:07:51] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Jul/2024 16:07:51] "GET /favicon.ico HTTP/1.1" 404 -
# [2024-07-18 16:08:02,098] ERROR in app: Exception on /marks/9 [GET]
# Traceback (most recent call last):
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Temp\ipykernel_8304\3186246098.py", line 11, in marks
#     p = model.predict([[hrs]])
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_base.py", line 306, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_base.py", line 285, in _decision_function
#     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py", line 633, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\parva\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py", line 1053, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# 127.0.0.1 - - [18/Jul/2024 16:08:02] "GET /marks/9 HTTP/1.1" 500 -
